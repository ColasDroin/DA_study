# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import ipywidgets as widgets
import io
import moviepy.editor as mpy
from PIL import Image
import seaborn as sns
plt.style.use('ggplot')
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
# Not italized latex
matplotlib.rcParams['mathtext.default'] = 'regular'
matplotlib.rcParams["font.weight"] = "light"
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('retina')
STUDY_NAME = "opt_flathv_75_1500_withBB_chroma15_1p4"


# To generate animations
def mpl_fig2array(plt):
    with io.BytesIO() as buffer:  # use buffer memory
        plt.savefig(buffer, format='png')
        buffer.seek(0)
        img = Image.open(buffer)
        return np.asarray(img)

# %%
# Load dataframe
df = pd.read_parquet(f"../{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

df
# Out:
#           normalized amplitude in xy-plane      q1      q2            nb  \
# name 1
# madx_000                             3.938  62.305  60.305  1.400000e+11
# madx_001                             3.594  62.305  60.306  1.400000e+11
# madx_002                             3.656  62.305  60.307  1.400000e+11
# madx_003                             3.719  62.305  60.308  1.400000e+11
# madx_004                             3.875  62.305  60.309  1.400000e+11
# ...                                    ...     ...     ...           ...
# madx_493                             5.250  62.324  60.323  1.400000e+11
# madx_494                             5.750  62.324  60.324  1.400000e+11
# madx_495                             4.688  62.324  60.325  1.400000e+11
# madx_496                             5.250  62.324  60.326  1.400000e+11
# madx_497                             5.219  62.324  60.327  1.400000e+11
#
#           on_x1  oct_current  bunch_nb
# name 1
# madx_000  250.0         60.0    1963.0
# madx_001  250.0         60.0    1963.0
# madx_002  250.0         60.0    1963.0
# madx_003  250.0         60.0    1963.0
# madx_004  250.0         60.0    1963.0
# ...         ...          ...       ...
# madx_493  250.0         60.0    1963.0
# madx_494  250.0         60.0    1963.0
# madx_495  250.0         60.0    1963.0
# madx_496  250.0         60.0    1963.0
# madx_497  250.0         60.0    1963.0
#
# [498 rows x 7 columns]

# %%
# Reshape for plotting
df_to_plot = df.pivot(index  = 'q2', columns = 'q1', values = 'normalized amplitude in xy-plane')
df_to_plot
# Out:
# q1      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# q2
# 60.305   3.938   3.844   3.969   3.781   3.812   3.844   4.094   4.156
# 60.306   3.594   3.719   4.000   3.875   3.656   4.000   3.906   3.906
# 60.307   3.656   3.562   3.719   3.781   3.688   4.125   3.562   4.156
# 60.308   3.719   3.625   3.469   3.594   3.781   3.500   3.938   4.219
# 60.309   3.875   3.562   3.375   3.750   3.719   3.938   4.000   4.906
# 60.310   3.719   3.844   3.781   3.625   3.750   3.688   4.969   5.281
# 60.311   3.812   3.938   3.906   3.719   4.375   4.188   5.188   5.469
# 60.312   3.875   3.875   3.812   3.719   3.375   4.875   5.344   5.750
# 60.313   3.875   3.906   3.719   3.469   5.094   5.562   5.812   5.750
# 60.314   3.656   3.688   3.781   4.156   4.938   5.375   5.875   5.781
# 60.315   3.938   3.875   3.969   3.750   5.344   5.844   5.719   5.688
# 60.316   4.094   3.625   4.031   3.938   5.531   5.938   5.938   5.531
# 60.317   3.844   3.625   4.125   4.156   4.156   5.625   5.469   5.656
# 60.318   3.625   3.750   4.281   4.125   5.688   5.906   5.219   5.438
# 60.319   4.000   4.000   4.250   3.750   5.406   5.500   5.438   5.594
# 60.320   4.281   3.844   3.906   4.094   5.312   5.406   5.719   5.500
# 60.321   4.219   4.000   3.906   4.094   5.594   5.312   5.656   5.219
# 60.322   4.125   4.031   3.969   3.938   5.062   4.812   5.531   5.250
# 60.323   4.125   4.062   3.875   4.500   4.688   4.875   4.438   4.781
# 60.324   3.750   3.875   3.969   3.750   3.781   4.469   4.156   4.250
# 60.325   3.688   3.906   3.812   3.750   3.656   4.000   4.031   3.719
# 60.326   3.500   3.844   3.625   3.531   3.688   3.656   3.531   3.844
# 60.327   3.375   3.562   3.250   3.375   3.375   3.406   3.375   3.562
# 60.328   3.000   3.094   2.938   3.062   3.219   3.156   3.219   2.938
# 60.329   2.781   2.969   2.625   2.906   2.812   2.812   2.750   2.750
#
# q1      62.313  62.314  62.315  62.316  62.317  62.318  62.319  62.320  \
# q2
# 60.305   3.750   4.219   4.188   4.250   4.562   4.250   4.406   4.438
# 60.306   4.031   3.844   4.188   4.000   4.094   4.469   4.406   4.688
# 60.307   3.688   4.094   4.062   4.344   3.812   4.469   4.719   4.844
# 60.308   3.875   4.062   4.531   4.250   4.562   5.469   5.156   5.156
# 60.309   4.500   5.438   5.594   5.906   5.406   5.625   5.125   4.906
# 60.310   5.375   5.625   5.562   5.438   5.531   5.750   5.812   5.344
# 60.311   5.594   5.531   5.844   5.719   5.719   5.469   5.375   5.344
# 60.312   5.844   5.438   5.594   5.656   5.344   5.656   5.562   5.438
# 60.313   5.719   5.562   5.688   5.938   6.219   5.750   5.281   5.812
# 60.314   5.188   5.781   5.750   5.625   6.000   6.031   6.250   5.594
# 60.315   5.312   5.438   5.500   6.094   6.500   6.500   6.406   6.000
# 60.316   5.781   5.562   5.500   6.031   5.969   6.312   6.438   6.406
# 60.317   5.719   5.625   6.094   6.281   7.031   6.562   6.688   6.312
# 60.318   5.438   5.000   6.062   6.844   6.656   6.438   6.875   6.562
# 60.319   5.438   5.719   6.312   6.375   6.844   6.594   6.844   6.625
# 60.320   5.469   5.375   5.938   6.750   6.969   6.875   6.031   6.656
# 60.321   5.562   5.000   6.125   6.531   6.344   6.594   6.750   5.844
# 60.322   5.188   5.344   5.469   5.719   6.188   6.125   6.375   6.375
# 60.323   4.969   4.906   5.125   5.281   5.344   5.625   5.625   5.812
# 60.324   4.344   4.812   4.781   4.812   5.031   4.906   5.156   5.344
# 60.325   4.125   3.906   4.094   4.219   4.656   4.344   4.781   4.812
# 60.326   3.594   3.875   3.719   4.094   4.250   4.281   4.250   4.219
# 60.327   3.344   3.500   3.750   3.688   3.562   3.875   3.844   3.688
# 60.328   3.469   3.156   3.469   3.000   3.375   3.469   3.375   3.500
# 60.329   2.906   2.969   2.969   2.875   2.938   2.625   2.812   2.938
#
# q1      62.321  62.322  62.323  62.324
# q2
# 60.305   4.281   3.562   3.531   4.156
# 60.306   4.219   3.750   3.719   4.688
# 60.307   4.438   4.125   3.688   3.781
# 60.308   4.781   3.938   3.844   3.781
# 60.309   4.594   4.312   3.781   4.156
# 60.310   4.656   4.031   4.125   4.156
# 60.311   4.875   4.344   4.156   3.875
# 60.312   5.156   4.438   4.375   4.219
# 60.313   5.812   4.656   4.312   4.062
# 60.314   5.156   5.062   4.719   3.812
# 60.315   5.406   4.906   4.688   4.219
# 60.316   5.562   5.250   4.844   4.344
# 60.317   5.719   5.344   4.750   4.688
# 60.318   5.969   5.438   5.000   4.750
# 60.319   6.031   5.688   5.156   4.812
# 60.320   6.031   5.906   5.750   5.219
# 60.321   5.906   6.156   5.594   4.906
# 60.322   5.625   5.438   6.281   5.750
# 60.323   6.219   5.312   5.750   5.250
# 60.324   5.344   5.875   4.500   5.750
# 60.325   4.906   5.094   5.188   4.688
# 60.326   4.500   4.531   4.812   5.250
# 60.327   3.844   4.062   3.969   5.219
# 60.328   3.094   3.781   3.688     NaN
# 60.329   2.750   3.031   2.969     NaN

# %%
def latex_float(f):
    float_str = "{0:.2g}".format(f)
    if "e" in float_str:
        base, exponent = float_str.split("e")
        return r"${0} \times 10^{{{1}}}$".format(base, int(exponent))
    else:
        return float_str
    
def plot_heatmap(df_to_plot):
    # Get numpy array from dataframe
    data_array = df_to_plot.to_numpy()

    fig, ax = plt.subplots()
    im = ax.imshow(data_array, cmap="coolwarm_r")
    ax.invert_yaxis()

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(df_to_plot.columns))[::2], labels=df_to_plot.columns[::2])
    ax.set_yticks(np.arange(len(df_to_plot.index))[::2], labels=df_to_plot.index[::2])

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(len(df_to_plot.index)):
        for j in range(len(df_to_plot.columns)):
            text = ax.text(
                j, i, f"{data_array[i, j]:.1f}", ha="center", va="center", color="w", fontsize=4
            )

    CSS = ax.contour(
        np.arange(0.5, data_array.shape[1]),
        np.arange(0.5, data_array.shape[0]),
        data_array,
        colors="black",
        levels=list(np.arange(3,6,0.5)) + list(np.arange(6.5,10,0.5)),
        linewidths=0.2,
    )
    ax.clabel(CSS, inline=True, fontsize=6)
    CS2 = ax.contour(
        np.arange(0.5, data_array.shape[1]),
        np.arange(0.5, data_array.shape[0]),
        data_array,
        colors="green",
        levels=[6],
        linewidths=1,
    )
    ax.clabel(CS2, inline=1, fontsize=6)


    # ! Diagonal lines must be plotted after the contour lines, because of bug in matplotlib
    # Identity line
    ax.plot([0, 1000], [0, 1000], color="black", linestyle="--", linewidth=1)
    # plus minus 0.05 line (Q increment is 10**-3)
    ax.plot([0, 1000], [5, 1005], color="tab:blue", linestyle="--", linewidth=1)
    ax.plot([0, 1000], [-5, 995], color="tab:blue", linestyle="--", linewidth=1)

    ax.set_title(
        "HL-LHC v1.5. Flat optics. End of levelling."
        + "\n"
        + f"$N_b = $"
        + latex_float(df.nb.min())
        + "ppb, "
        + r"$\beta^{*}_{y,IP1} = 7.5$ cm"
        + ", "
        + r"$\beta^{*}_{x,IP1} = 18$ cm"
        + ", "
        + r"$\Phi/2_{IP1(H)/5(V)} = 250$ $\mu rad$"
        + "\n"
        + "CC ON, "
        + r"$\sigma_{z} = 7.61$ $cm$"
        + ", "
        + r"$\Phi/2_{IP8,V} = 170$ $\mu rad$"
        + ", "
        + r"$\epsilon_{n} = 2.5$ $\mu m$"
        + ", "
        + r"Q' = 15"
        + ", "
        + r"$I_{MO} = 60$ $A$"
        + ", "
        + r"$C^-=10^{-3}$",
        fontsize = 10)
    ax.set_xlabel("Horizontal tune " + r"$Q_x$")
    ax.set_ylabel("Vertical tune " + r"$Q_y$")
    ax.set_xlim(0 - 0.5, data_array.shape[1] - 0.5)
    ax.set_ylim(0 - 0.5, data_array.shape[0] - 0.5)


    # Create colorbar
    cbar = ax.figure.colorbar(im, ax=ax)
    cbar.ax.set_ylabel("Minimum DA (" + r"$\sigma$" + ")", rotation=90, va="bottom", labelpad=15)
    plt.grid(visible=None)
    plt.savefig("output_" + STUDY_NAME + ".pdf",  bbox_inches='tight')
    plt.show()

plot_heatmap(df_to_plot)

# %% [markdown]
# ### Make a widget to see how heatmap evolves with number of turn

# %%
df_evolution = pd.read_parquet(f"../{STUDY_NAME}/da_evolution.parquet")
df_evolution = df_evolution.round(3)

# Only keep relevant columns
df_evolution = df_evolution[['name 1', "q1", "q2", "nb", "normalized amplitude in xy-plane", "on_x1", "oct_current", "bunch_nb", "at_turn"]]
df_evolution
# Out:
#       name 1      q1      q2            nb  normalized amplitude in xy-plane  \
# 80  madx_000  62.305  60.305  1.400000e+11                             4.094
# 81  madx_000  62.305  60.305  1.400000e+11                             3.938
# 82  madx_000  62.305  60.305  1.400000e+11                             4.062
# 83  madx_000  62.305  60.305  1.400000e+11                             4.000
# 84  madx_000  62.305  60.305  1.400000e+11                             4.062
# ..       ...     ...     ...           ...                               ...
# 80  madx_497  62.324  60.327  1.400000e+11                             8.500
# 81  madx_497  62.324  60.327  1.400000e+11                             8.781
# 82  madx_497  62.324  60.327  1.400000e+11                             8.750
# 83  madx_497  62.324  60.327  1.400000e+11                             8.438
# 84  madx_497  62.324  60.327  1.400000e+11                             8.906
#
#     on_x1  oct_current  bunch_nb  at_turn
# 80  250.0         60.0      1963   924174
# 81  250.0         60.0      1963   864807
# 82  250.0         60.0      1963   819406
# 83  250.0         60.0      1963   795301
# 84  250.0         60.0      1963   750779
# ..    ...          ...       ...      ...
# 80  250.0         60.0      1963      533
# 81  250.0         60.0      1963      517
# 82  250.0         60.0      1963      510
# 83  250.0         60.0      1963      507
# 84  250.0         60.0      1963      401
#
# [296902 rows x 9 columns]

# %%
def filter_dataframe(df, n_turns= 1000000):
    # Only keep data up to n_turns, to emulate smaller simulations
    df_filtered = df[df["at_turn"] <= n_turns]
    df_filtered = pd.DataFrame(
        [
            df_filtered.groupby("name 1")["normalized amplitude in xy-plane"].min(),
            df_filtered.groupby("name 1")["q1"].mean(),
            df_filtered.groupby("name 1")["q2"].mean(),
            df_filtered.groupby("name 1")["nb"].mean(),
            df_filtered.groupby("name 1")["on_x1"].mean(),
            df_filtered.groupby("name 1")["oct_current"].mean(),
            df_filtered.groupby("name 1")["bunch_nb"].mean(),
        ]
    ).transpose()

    # Round otherwise pivot won't work
    df_filtered = df_filtered.round(3)

    # Prepare for plotting
    df_filtered = df_filtered.pivot(index  = 'q2', columns = 'q1', values = 'normalized amplitude in xy-plane')
    return df_filtered

# %%
def plot_heatmap_evolution(
    df_evolution,
    animation=False,
    gif_path="test.gif",
    fps=60,
    duration=5,
):
    # Initally filter for 1M turns
    df_to_plot = filter_dataframe(df_evolution, n_turns=1000000)

    # Get numpy array from dataframe
    data_array = df_to_plot.to_numpy()

    fig, ax = plt.subplots(figsize=(10, 10))

    im = ax.imshow(data_array, cmap="coolwarm_r", vmin = 2, vmax = 10, interpolation='none')
    ax.invert_yaxis()

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(df_to_plot.columns))[::2], labels=df_to_plot.columns[::2])
    ax.set_yticks(np.arange(len(df_to_plot.index))[::2], labels=df_to_plot.index[::2])

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Identity line
    ax.plot([0, 1000], [0, 1000], color="black", linestyle="--", linewidth=1)
    # plus minus 0.05 line (Q increment is 10**-3)
    ax.plot([0, 1000], [5, 1005], color="tab:blue", linestyle="--", linewidth=1)
    ax.plot([0, 1000], [-5, 995], color="tab:blue", linestyle="--", linewidth=1)

    ax.set_xlabel("Horizontal tune " + r"$Q_x$")
    ax.set_ylabel("Vertical tune " + r"$Q_y$")
    ax.set_xlim(0 - 0.5, data_array.shape[1] - 0.5)
    ax.set_ylim(0 - 0.5, data_array.shape[0] - 0.5)

    # Create colorbar
    norm = matplotlib.colors.Normalize(vmin=2, vmax=10)
    cbar = ax.figure.colorbar(im, ax=ax, norm=norm,)
    cbar.ax.set_ylabel("Minimum DA (" + r"$\sigma$" + ")", rotation=90, va="bottom", labelpad=15)
    plt.grid(visible=None)

    # Update value with widget
    k_min = 1000
    k_max = 1000000
    k_step = duration / fps
    slider_range = np.linspace(k_min, k_max, duration * fps)
    int_slider = widgets.IntSlider(
        value=1000000, min=k_min, max=k_max, step=k_step, description=r"N", continuous_update=False
    )

    def update(change):
        global CS1, CS2, CS1_label, CS2_label
        # Get numpy array from dataframe
        df_to_plot = filter_dataframe(df_evolution, n_turns=int_slider.value)
        data_array = df_to_plot.to_numpy()

        # Update image
        im.set_data(data_array)

        # Update contour lines, deleting old ones (including labels)
        try:
            for coll in CS1.collections:
                coll.remove()
            for coll in CS2.collections:
                coll.remove()
            for str in CS1_label:
                str.remove()
            for str in CS2_label:
                str.remove()
        except:
            pass
        CS1 = ax.contour(
            np.arange(0.5, data_array.shape[1]),
            np.arange(0.5, data_array.shape[0]),
            data_array,
            colors="black",
            levels=list(np.arange(3,6,0.5)) + list(np.arange(6.5,10,0.5)),
            linewidths=0.2,
        )
        CS1_label = ax.clabel(CS1, inline=1, fontsize=15)
        CS2 = ax.contour(
            np.arange(0.5, data_array.shape[1]),
            np.arange(0.5, data_array.shape[0]),
            data_array,
            colors="green",
            levels=[6],
            linewidths=1,
        )
        CS2_label = ax.clabel(CS2, inline=1, fontsize=15)
        
        # Add text to indicate slider value
        ax.set_title(
            "HL-LHC v1.5. Flat optics. End of levelling." + f" $N = {int_slider.value}$"
            + "\n"
            + f"$N_b = $"
            + latex_float(df.nb.min())
            + "ppb, "
            + r"$\beta^{*}_{y,IP1} = 7.5$ cm"
            + ", "
            + r"$\beta^{*}_{x,IP1} = 18$ cm"
            + ", "
            + r"$\Phi/2_{IP1(H)/5(V)} = 250$ $\mu rad$"
            + "\n"
            + "CC ON, "
            + r"$\sigma_{z} = 7.61$ $cm$"
            + ", "
            + r"$\Phi/2_{IP8,V} = 170$ $\mu rad$"
            + ", "
            + r"$\epsilon_{n} = 2.5$ $\mu m$"
            + ", "
            + r"Q' = 15"
            + ", "
            + r"$I_{MO} = 60$ $A$"
            + ", "
            + r"$C^-=10^{-3}$"
        )
        fig.canvas.draw_idle()

    int_slider.observe(update, "value")

    # Function to convert interaction to an animation
    def make_frame(t):
        idx = int(round(t * fps))
        int_slider.value = slider_range[idx]
        update(None)
        return mpl_fig2array(plt)

    if animation:
        animation = mpy.VideoClip(make_frame, duration=duration)
        animation.write_gif(gif_path, fps=fps, program = "ImageMagick", opt = "optimizetransparency", fuzz = 0)
        #animation.write_videofile("test.mp4", codec = 'mpeg4', fps = fps)

    return int_slider

# %%
# %matplotlib widget
vbox = plot_heatmap_evolution(df_evolution, animation=False, duration = 10, fps = 30)
display(vbox)
# Out:
# IntSlider(value=1000000, continuous_update=False, description='N', max=1000000, min=1000, step=0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# Compute evolution area DA>6sigma for each N
# Also get evolution of the position of the point with the maximum DA for each N

range_n_turns = range(11000, 1000001, 10000)
l_area = []
ll_position_best = []
for n_turns in range_n_turns:
    array_to_plot= filter_dataframe(df_evolution, n_turns=n_turns).to_numpy()
    l_area.append(np.sum([array_to_plot > 6]))
    l_position_best = []
    for i in range(5):
        # ! Careful, q1 is y and q2 is x
        l_position_best.append(np.unravel_index(np.nanargmax(array_to_plot), array_to_plot.shape))
        array_to_plot[l_position_best[-1]] = 0
    ll_position_best.append(l_position_best)
    
# Plot evolution area DA>6sigma for each N
plt.figure()
plt.plot(range_n_turns, l_area)
plt.xlabel(r"N turns")
plt.ylabel(r"Area | DA> 6$\sigma$")
plt.title(r"Evolution of area enclosed by the contour $DA>6\sigma$ with the length of the simulation", fontsize=10)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot with a line whose color is proportional to n_turns
plt.figure()
for i, l_position in enumerate(ll_position_best):
    # ! Careful, x and y reversed
    for j, (y, x) in enumerate(l_position):
        # Add some jiggle to the points so that they are visible
        x += np.random.normal(0, 0.1)
        y += np.random.normal(0, 0.1)
        if i == len(ll_position_best) - 1:
            plt.scatter(x, y, color=sns.color_palette()[j], alpha=i / len(ll_position_best), marker="+", label = f"Best: {j}")
        else:
            plt.scatter(x, y, color=sns.color_palette()[j], alpha=np.sqrt(i / len(ll_position_best)), marker="+")
# plt.plot([x[1] for x in l_position], [x[0] for x in l_position], alpha = )
plt.xlabel("Horizontal tune " + r"$Q_x$")
plt.ylabel("Vertical tune " + r"$Q_y$")
# Show all ticks and label them with the respective list entries
plt.xticks(np.arange(len(df_to_plot.columns))[::2], labels=df_to_plot.columns[::2])
plt.yticks(np.arange(len(df_to_plot.index))[::2], labels=df_to_plot.index[::2])
plt.xlim(0 - 0.5, array_to_plot.shape[1] - 0.5)
plt.ylim(0 - 0.5, array_to_plot.shape[0] - 0.5)
plt.title("Evolution of the position of the 5 best WP with the length of the simulation", fontsize=10)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
